# %% [markdown]
# # Requirements

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.8/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)

# %%
from pmdarima import auto_arima

# %%
# !pip install fedot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fedot in /usr/local/lib/python3.8/dist-packages (0.6.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from fedot) (3.3.3)
# Requirement already satisfied: hyperopt==0.2.7 in /usr/local/lib/python3.8/dist-packages (from fedot) (0.2.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from fedot) (1.0.2)
# Requirement already satisfied: xgboost>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from fedot) (1.7.2)
# Requirement already satisfied: SALib>=1.3.* in /usr/local/lib/python3.8/dist-packages (from fedot) (1.4.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fedot) (4.64.1)
# Requirement already satisfied: matplotlib>=3.3.1 in /usr/local/lib/python3.8/dist-packages (from fedot) (3.6.2)
# Requirement already satisfied: scikit-optimize>=0.7.4 in /usr/local/lib/python3.8/dist-packages (from fedot) (0.9.0)
# Requirement already satisfied: ete3>=3.1.* in /usr/local/lib/python3.8/dist-packages (from fedot) (3.1.2)
# Requirement already satisfied: networkx!=2.7.*,!=2.8.1,!=2.8.2,!=2.8.3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from fedot) (2.8.8)
# Requirement already satisfied: psutil>=5.9.2 in /usr/local/lib/python3.8/dist-packages (from fedot) (5.9.4)
# Requirement already satisfied: testfixtures>=6.18.* in /usr/local/lib/python3.8/dist-packages (from fedot) (7.0.4)
# Requirement already satisfied: seaborn>=0.9.* in /usr/local/lib/python3.8/dist-packages (from fedot) (0.11.2)
# Requirement already satisfied: joblib>=0.17.* in /usr/local/lib/python3.8/dist-packages (from fedot) (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from fedot) (1.3.5)
# Requirement already satisfied: func-timeout==4.3.5 in /usr/local/lib/python3.8/dist-packages (from fedot) (4.3.5)
# Requirement already satisfied: typing>=3.7.* in /usr/local/lib/python3.8/dist-packages (from fedot) (3.7.4.3)
# Requirement already satisfied: pyvis==0.2.1 in /usr/local/lib/python3.8/dist-packages (from fedot) (0.2.1)
# Requirement already satisfied: pytest>=6.2.* in /usr/local/lib/python3.8/dist-packages (from fedot) (7.2.0)
# Requirement already satisfied: catboost>=0.25.* in /usr/local/lib/python3.8/dist-packages (from fedot) (1.1.1)
# Requirement already satisfied: anytree>=2.8.* in /usr/local/lib/python3.8/dist-packages (from fedot) (2.8.0)
# Requirement already satisfied: numpy>=1.16.* in /usr/local/lib/python3.8/dist-packages (from fedot) (1.21.6)
# Requirement already satisfied: statsmodels>=0.12.0 in /usr/local/lib/python3.8/dist-packages (from fedot) (0.13.5)
# Requirement already satisfied: requests>=2.* in /usr/local/lib/python3.8/dist-packages (from fedot) (2.23.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.2.7->fedot) (0.10.9.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.2.7->fedot) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.2.7->fedot) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.2.7->fedot) (0.16.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from hyperopt==0.2.7->fedot) (1.5.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.2.1->fedot) (7.9.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.2.1->fedot) (3.0.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.2.1->fedot) (2.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (from catboost>=0.25.*->fedot) (5.5.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.8/dist-packages (from catboost>=0.25.*->fedot) (0.10.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (5.6.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.2.1->fedot) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython>=5.3.0->pyvis==0.2.1->fedot) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.9.6->pyvis==0.2.1->fedot) (2.0.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from lightgbm>=3.0.0->fedot) (0.38.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.3.1->fedot) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.3.0->fedot) (2022.6)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.3.0->pyvis==0.2.1->fedot) (0.2.5)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.*->fedot) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.*->fedot) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.*->fedot) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.*->fedot) (22.1.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest>=6.2.*->fedot) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.*->fedot) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.*->fedot) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.*->fedot) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.*->fedot) (2.10)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from SALib>=1.3.*->fedot) (0.70.14)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->fedot) (3.1.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.8/dist-packages (from scikit-optimize>=0.7.4->fedot) (21.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from pyaml>=16.9->scikit-optimize>=0.7.4->fedot) (6.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.8/dist-packages (from statsmodels>=0.12.0->fedot) (0.5.3)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.8/dist-packages (from multiprocess->SALib>=1.3.*->fedot) (0.3.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython>=5.3.0->pyvis==0.2.1->fedot) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly->catboost>=0.25.*->fedot) (8.1.0)

# %%
from fedot.core.data.multi_modal import MultiModalData
from fedot.core.data.data import InputData
from fedot.core.pipelines.pipeline import Pipeline
from fedot.core.pipelines.node import PrimaryNode, SecondaryNode
from fedot.core.repository.dataset_types import DataTypesEnum
from fedot.core.repository.tasks import Task, TaskTypesEnum, TsForecastingParams
from fedot.core.data.data_split import train_test_data_setup

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import scipy
from tqdm.notebook import tqdm

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa import stattools
from scipy.ndimage import gaussian_filter1d
from scipy import signal
from statsmodels.tsa.ar_model import AutoReg
import statsmodels.tsa.api  as smt
from statsmodels.tsa.ar_model import AutoReg

from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split
from statsmodels.tsa.statespace.sarimax import SARIMAX
from itertools import product
from numpy.linalg import LinAlgError

warnings.filterwarnings('ignore')
plt.rcParams['font.size'] = 12.0
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv('Turbine_Data.csv')#, index_col=0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-0ff5f44f18da> in <module>
# ----> 1 df = pd.read_csv('Turbine_Data.csv')#, index_col=0)
#       2 df.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /usr/local/lib/python3.8/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Turbine_Data.csv'

# %%
# df = pd.read_csv('Turbine_Data.csv')#, index_col=0)
df.drop(inplace=True, columns=['Blade1PitchAngle', 'Blade2PitchAngle', 'Blade3PitchAngle', 'WTG'])
df = df.dropna(axis=0)
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dc5eae4069ca> in <module>
#       1 # df = pd.read_csv('Turbine_Data.csv')#, index_col=0)
# ----> 2 df.drop(inplace=True, columns=['Blade1PitchAngle', 'Blade2PitchAngle', 'Blade3PitchAngle', 'WTG'])
#       3 df = df.dropna(axis=0)
#       4 df.info()
#
# NameError: name 'df' is not defined

# %%
df.to_csv('/content/Turbine_Data45.csv', index=False)

# %%
df.head()

# %%
df2 = pd.read_csv('Turbine_Data45.csv')#, index_col=0)
df2.head()

# %% [markdown]
# # Preprocessig with new dataset

# %%
df = pd.read_csv('Turbine_Data45.csv')

# %%
df = df.rename(columns={'Unnamed: 0': 'Date'})
df1 = df.iloc[30000:31400]

# %%
df1.head()
# Out:
#                             Date  ActivePower  AmbientTemperatue  \
# 30000  2019-11-25 18:20:00+00:00   484.811382          23.135894
# 30001  2019-11-25 18:30:00+00:00   473.886145          23.044191
# 30002  2019-11-25 18:40:00+00:00   410.817685          22.896918
# 30003  2019-11-25 18:50:00+00:00   425.636621          22.825172
# 30004  2019-11-25 19:00:00+00:00   403.702268          22.820358
#
#        BearingShaftTemperature  ControlBoxTemperature  \
# 30000                42.864679                    0.0
# 30001                42.589469                    0.0
# 30002                42.283699                    0.0
# 30003                42.087679                    0.0
# 30004                41.909716                    0.0
#
#        GearboxBearingTemperature  GearboxOilTemperature  GeneratorRPM  \
# 30000                  67.471107              58.901955   1160.744512
# 30001                  67.089858              58.866143   1164.178744
# 30002                  66.203717              58.518284   1099.922987
# 30003                  65.966496              58.311730   1121.525905
# 30004                  65.871333              58.187267   1102.214295
#
#        GeneratorWinding1Temperature  GeneratorWinding2Temperature  \
# 30000                     71.059386                     70.245864
# 30001                     69.943800                     69.073047
# 30002                     68.671986                     67.786732
# 30003                     67.879549                     66.982792
# 30004                     67.240854                     66.354474
#
#        HubTemperature  MainBoxTemperature  NacellePosition  ReactivePower  \
# 30000       32.995312           34.187500           173.50      99.035418
# 30001       32.990576           34.141677           175.75      97.104932
# 30002       32.977397           34.066667           169.00      83.383613
# 30003       32.890854           33.996761           169.00      86.624567
# 30004       32.233649           33.890022           169.00      82.993174
#
#         RotorRPM  TurbineStatus  WindDirection  WindSpeed
# 30000  10.401707            2.0         173.50   5.848312
# 30001  10.434384            2.0         175.75   5.926594
# 30002   9.859029            2.0         169.00   5.654822
# 30003  10.057160            2.0         169.00   5.743376
# 30004   9.886101            2.0         169.00   5.601631

# %%
df1.tail()
# Out:
#                             Date  ActivePower  AmbientTemperatue  \
# 31395  2019-12-07 13:30:00+00:00    -5.703843          22.659033
# 31396  2019-12-07 13:40:00+00:00    -5.776515          22.689633
# 31397  2019-12-07 13:50:00+00:00    -5.297811          22.614557
# 31398  2019-12-07 14:00:00+00:00    -5.479120          22.690502
# 31399  2019-12-07 14:10:00+00:00    -5.562889          22.716520
#
#        BearingShaftTemperature  ControlBoxTemperature  \
# 31395                28.263172                    0.0
# 31396                28.256155                    0.0
# 31397                28.254601                    0.0
# 31398                28.256586                    0.0
# 31399                28.255552                    0.0
#
#        GearboxBearingTemperature  GearboxOilTemperature  GeneratorRPM  \
# 31395                  41.927086              39.918735           0.0
# 31396                  41.923471              39.911043           0.0
# 31397                  41.930567              39.934951           0.0
# 31398                  41.925585              39.950024           0.0
# 31399                  41.924987              39.945067           0.0
#
#        GeneratorWinding1Temperature  GeneratorWinding2Temperature  \
# 31395                     31.712917                     31.522817
# 31396                     31.647467                     31.457150
# 31397                     31.597211                     31.406507
# 31398                     31.542140                     31.352322
# 31399                     31.491217                     31.296345
#
#        HubTemperature  MainBoxTemperature  NacellePosition  ReactivePower  \
# 31395       26.996611           35.963110       164.200000     -13.592530
# 31396       26.996744           35.937500       148.250000     -13.317937
# 31397       26.994691           35.886324       129.000000     -12.133637
# 31398       26.993717           35.821876       114.000000     -11.476812
# 31399       26.991639           35.762725       103.666667     -12.447525
#
#        RotorRPM  TurbineStatus  WindDirection  WindSpeed
# 31395       0.0        16384.0     164.200000   1.739156
# 31396       0.0        16384.0     148.250000   1.645661
# 31397       0.0        16384.0     129.000000   1.831605
# 31398       0.0        16384.0     114.000000   1.389322
# 31399       0.0        16384.0     103.666667   1.379390

# %%
plt.figure(figsize=(12,10))
df1.plot(x = 'Date', y = 'WindDirection', figsize=(9,6))
plt.xlabel(f'Date ' )
plt.ylabel(f'WindDirection')
plt.show()

plt.figure(figsize=(12,10))
df1.plot(x = 'Date', y = 'WindSpeed', figsize=(9,6))
plt.xlabel(f'Date ' )
plt.ylabel(f'WindSpeed')
plt.show()

# %% [markdown]
# # Step 1
# #### Choose about 3-6 variables from your dataset (2-3 – target variables, the rest - predictors).

# %%
df
# Out:
#                             Date  ActivePower  AmbientTemperatue  \
# 0      2018-08-19 16:10:00+00:00  1723.840739          27.559161
# 1      2018-08-19 16:20:00+00:00  1713.430541          27.516543
# 2      2018-08-19 16:40:00+00:00  1724.986578          27.538246
# 3      2018-08-19 17:10:00+00:00  1710.218095          27.454070
# 4      2018-08-19 17:20:00+00:00  1716.371633          27.404938
# ...                          ...          ...                ...
# 45714  2020-03-30 23:10:00+00:00    70.044465          27.523741
# 45715  2020-03-30 23:20:00+00:00    40.833474          27.602882
# 45716  2020-03-30 23:30:00+00:00    20.777790          27.560925
# 45717  2020-03-30 23:40:00+00:00    62.091039          27.810472
# 45718  2020-03-30 23:50:00+00:00    68.664425          27.915828
#
#        BearingShaftTemperature  ControlBoxTemperature  \
# 0                    47.471346                    0.0
# 1                    42.126495                    0.0
# 2                    47.375546                    0.0
# 3                    47.125813                    0.0
# 4                    41.924676                    0.0
# ...                        ...                    ...
# 45714                45.711129                    0.0
# 45715                45.598573                    0.0
# 45716                45.462045                    0.0
# 45717                45.343827                    0.0
# 45718                45.231610                    0.0
#
#        GearboxBearingTemperature  GearboxOilTemperature  GeneratorRPM  \
# 0                      76.799038              63.229199   1751.589089
# 1                      68.203331              63.155119   1759.218300
# 2                      76.601080              62.995341   1752.282056
# 3                      76.562569              62.964190   1751.914460
# 4                      67.924564              62.840194   1757.314711
# ...                          ...                    ...           ...
# 45714                  59.821165              55.193793   1029.870744
# 45715                  59.142038              54.798545   1030.160478
# 45716                  58.439439              54.380456   1030.137822
# 45717                  58.205413              54.079014   1030.178178
# 45718                  58.581716              54.080505   1029.834789
#
#        GeneratorWinding1Temperature  GeneratorWinding2Temperature  \
# 0                        111.337475                    110.699257
# 1                        111.219889                    110.578340
# 2                        110.953116                    110.334352
# 3                        110.820297                    110.191098
# 4                        110.730811                    110.098841
# ...                             ...                           ...
# 45714                     59.060367                     58.148777
# 45715                     58.452003                     57.550367
# 45716                     58.034071                     57.099335
# 45717                     57.795387                     56.847239
# 45718                     57.694813                     56.741040
#
#        HubTemperature  MainBoxTemperature  NacellePosition  ReactivePower  \
# 0           42.003815           40.437500            89.00       0.015372
# 1           37.336724           35.882182            89.00       0.279944
# 2           42.003815           40.238596            89.00      -0.225979
# 3           42.003815           40.000000            95.00       0.523854
# 4           37.333527           35.506944            94.25       0.607706
# ...               ...                 ...              ...            ...
# 45714       39.008931           36.476562           178.00      13.775785
# 45715       39.006759           36.328125           178.00       8.088928
# 45716       39.003815           36.131944           178.00       4.355978
# 45717       39.003815           36.007805           190.00      12.018077
# 45718       39.003815           35.914062           203.00      14.439669
#
#         RotorRPM  TurbineStatus  WindDirection  WindSpeed
# 0      15.702706            2.0          89.00  15.061125
# 1      15.780975            2.0          89.00  11.791917
# 2      15.703549            2.0          89.00  13.433922
# 3      15.725234            2.0          95.00  13.016989
# 4      15.760685            2.0          94.25  12.377344
# ...          ...            ...            ...        ...
# 45714   9.234004            2.0         178.00   3.533445
# 45715   9.229370            2.0         178.00   3.261231
# 45716   9.236802            2.0         178.00   3.331839
# 45717   9.237374            2.0         190.00   3.284468
# 45718   9.235532            2.0         203.00   3.475205
#
# [45719 rows x 18 columns]

# %%
# df = df.rename(columns={'William%R': 'William'})

# %%
df = df1

# %%
df = df.convert_dtypes()

datetimes = pd.to_datetime(df["Date"])
df["Date"] = datetimes

target_columns = ['WindDirection', 'WindSpeed']
predict_columns = ['ActivePower', 'RotorRPM', 'AmbientTemperatue', 'ReactivePower']
target_df = df[['Date']+target_columns+predict_columns]
target_df
# Out:
#                            Date  WindDirection  WindSpeed  ActivePower  \
# 30000 2019-11-25 18:20:00+00:00          173.5   5.848312   484.811382
# 30001 2019-11-25 18:30:00+00:00         175.75   5.926594   473.886145
# 30002 2019-11-25 18:40:00+00:00          169.0   5.654822   410.817685
# 30003 2019-11-25 18:50:00+00:00          169.0   5.743376   425.636621
# 30004 2019-11-25 19:00:00+00:00          169.0   5.601631   403.702268
# ...                         ...            ...        ...          ...
# 31395 2019-12-07 13:30:00+00:00          164.2   1.739156    -5.703843
# 31396 2019-12-07 13:40:00+00:00         148.25   1.645661    -5.776515
# 31397 2019-12-07 13:50:00+00:00          129.0   1.831605    -5.297811
# 31398 2019-12-07 14:00:00+00:00          114.0   1.389322     -5.47912
# 31399 2019-12-07 14:10:00+00:00     103.666667    1.37939    -5.562889
#
#         RotorRPM  AmbientTemperatue  ReactivePower
# 30000  10.401707          23.135894      99.035418
# 30001  10.434384          23.044191      97.104932
# 30002   9.859029          22.896918      83.383613
# 30003   10.05716          22.825172      86.624567
# 30004   9.886101          22.820358      82.993174
# ...          ...                ...            ...
# 31395        0.0          22.659033      -13.59253
# 31396        0.0          22.689633     -13.317937
# 31397        0.0          22.614557     -12.133637
# 31398        0.0          22.690502     -11.476812
# 31399        0.0           22.71652     -12.447525
#
# [1400 rows x 7 columns]

# %%
plt.figure(figsize=(12,10))
target_df.plot(x = 'Date', y = 'WindSpeed', figsize=(9,6))
plt.xlabel(f'Date ' )
plt.ylabel(f'WindSpeed')
plt.show()

plt.figure(figsize=(12,10))
target_df.plot(x = 'Date', y = 'WindDirection', figsize=(9,6))
plt.xlabel(f'Date ' )
plt.ylabel(f'WindDirection')
plt.show()

# %% [markdown]
# # Step 2
# #### Analyze stationarity of a process (for mathematical expectation and variance) for all chosen variables. Make them more stationary if needed.

# %%
import statsmodels.tsa.api as smt
for column in target_columns+predict_columns:
    result = smt.stattools.adfuller(target_df[column])
    print(f'Augmented Dickey-Fuller test for {column}:\nStatistic value = {result[0]}\np-value = {result[1]}\n')
# Out:
# Augmented Dickey-Fuller test for WindDirection:
# Statistic value = -6.292317650067943
# p-value = 3.5743369397650344e-08
#
# Augmented Dickey-Fuller test for WindSpeed:
# Statistic value = -4.061611107370731
# p-value = 0.0011201270876065542
#
# Augmented Dickey-Fuller test for ActivePower:
# Statistic value = -5.509118949459489
# p-value = 1.9905838029603977e-06
#
# Augmented Dickey-Fuller test for RotorRPM:
# Statistic value = -3.1385266084978904
# p-value = 0.02383033677754307
#
# Augmented Dickey-Fuller test for AmbientTemperatue:
# Statistic value = -4.897874291604985
# p-value = 3.5208147033406554e-05
#
# Augmented Dickey-Fuller test for ReactivePower:
# Statistic value = -5.622861054732123
# p-value = 1.1346436811302795e-06

# %% [markdown]
# # Step 3
# #### Analyze covariance or correlation function for chosen target variables and mutual correlation functions among predictors and targets.

# %%
target_columns
# Out:
# ['WindDirection', 'WindSpeed']

# %%
for column in target_columns:
    print("\t\t\tPlot for target:", column)
    fig, (ax1, ax2) = plt.subplots(2,1,figsize=(10,8))
    ax1.plot(stattools.acovf(target_df[column], fft=False))
    ax2.plot(stattools.acovf(target_df[column], nlag=200, fft=False)[25:])
    plt.xlabel(f'Lags' )
    # plt.title(f'High autocovariance')
    plt.show()
# Out:
# 			Plot for target: WindDirection
# 			Plot for target: WindSpeed

# %%
target_columns
# Out:
# ['WindDirection', 'WindSpeed']

# %%
for column in target_columns:
  print("\t\t\tPlots for target:", column)
  fig, (ax1, ax2) = plt.subplots(2,1,figsize=(10,8))
  plot_acf(target_df[column], ax = ax1)
  plot_pacf(target_df[column], ax = ax2)
  plt.show()
# Out:
# 			Plots for target: WindDirection
# 			Plots for target: WindSpeed

# %%
corrMatrix = target_df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
for target in target_columns:
    for predictor in predict_columns:  
        fig, axs = plt.subplots(1,figsize=(8, 7))
        axs.xcorr(target_df[target].astype(float), target_df[predictor].astype(float), usevlines=True, maxlags=45, normed=True, lw=2)
        axs.set_title(f"{target}: {predictor}")
        axs.set_ylabel('Correlation rate')
        axs.set_xlabel('Date')

# %% [markdown]
# # Step 4 - Filter high frequencies (noise) with chosen 2 filters for target variables.

# %%
# Rolling mean filtering
i=1
filtered_df = target_df

for item in target_columns:
    variable_roll = target_df[item].head(14).values
    variable_roll = np.append(variable_roll, target_df[item].rolling(window=15).mean().iloc[15-1:].values)
    i+=1
    filtered_df[f'mean_{item}'] = variable_roll
    fig, axs = plt.subplots(figsize=(9, 6),squeeze=False)
    plt.plot(list(target_df['Date']), list(target_df[item]), label = f'Original')
    plt.plot(list(target_df['Date']), list(variable_roll), label = f'Roll mean')
    plt.title(f'Rolling mean filtering of {item}')
    plt.legend(loc='best')

# %%
# gaussian filter
for item in target_columns:
    fig, axs = plt.subplots(figsize=(9, 6),squeeze=False)
    gauss_column = gaussian_filter1d(np.array(target_df[item], np.float), 0.90)
    filtered_df[f'gauss_{item}'] = gauss_column
    plt.plot(list(target_df['Date']), list(list(target_df[item])), label = f'Original')
    plt.plot(list(target_df['Date']), list(gauss_column), label = f'Gauss filter')
    plt.title(f'Gaussian filtering of {item}')
    plt.legend(loc='best')
    
# print(filtered_df)

# %% [markdown]
# # Step 5 - Estimate spectral density function with and without filtering.

# %%
window_size = 15
blackman = signal.blackman(M=window_size)


#item_columns = target_columns + [f'mean_{item}' for item in target_columns] + [f'gauss_{item}' for item in target_columns]

for item in target_columns:
    f, Pxx_den = signal.welch(target_df[item], fs=1, scaling='spectrum', nfft = 1000, nperseg=100)
    f_window, Pxx_den_window = signal.welch(target_df[f'mean_{item}'], fs=1, window = blackman, nfft = 1000, scaling='spectrum')
    f_window2, Pxx_den_window2 = signal.welch(target_df[f'gauss_{item}'], fs=1, window = blackman, nfft = 1000, scaling='spectrum')

    #f_window_bart, Pxx_den_window_bart = signal.welch(target_df[item], fs=1, window = bartlett, nfft = 1000, scaling='spectrum')

    Pxx_den = [item.real for item in Pxx_den]
    f =  [item.real for item in f]
    f_window = [item.real for item in f_window]
    Pxx_den_window = [item.real for item in Pxx_den_window]
    f_window2 = [item.real for item in f_window2]
    Pxx_den_window2 = [item.real for item in Pxx_den_window2]
    #f_window_bart = [item.real for item in f_window_bart]
    #Pxx_den_window_bart = [item.real for item in Pxx_den_window_bart]

    plt.plot(f, Pxx_den, linewidth=2, label = 'original')
    plt.plot(f_window, Pxx_den_window, label = 'mean filter')
    plt.plot(f_window2, Pxx_den_window2, label = 'gauss filter')

    plt.xlabel('frequency [Hz]')
    plt.ylabel('PSD [V**2/Hz]')
    plt.legend(loc='best')
    plt.title(f'Spectral density for {item}')
    plt.xlim((0,0.2))
    plt.show()

# %% [markdown]
# # Step 6 - Built auto-regression model filtered and non-filtered data. To analyze residual error and to define appropriate order of model.

# %%
test, train = train_test_split(target_df[target_columns[0]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

# %%
ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: 9294.317315403827
# AIC value: 8893.334564674575
# AIC value: 9292.144573483434
# AIC value: 8894.291291899985
# AIC value: 9291.148368813268
# AIC value: 8893.375860692106
# AIC value: 9293.059612247731
# AIC value: 8895.245441619858
# AIC value: 9294.93403580692
# AIC value: 8897.235582403104
# AIC value: 9296.514239111973
# AIC value: 8899.06512921643
# AIC value: 9292.554223260395
# AIC value: 8894.39050003752
# AIC value: 9232.033121184497
# AIC value: 8854.98969345442
# AIC value: 9293.02979794503
# AIC value: 8895.242952963792
# AIC value: 9295.023279601864
# AIC value: 8897.250452861012
# AIC value: 9297.014253458132
# AIC value: 8899.242419526205
# AIC value: 9298.443056977327
# AIC value: 8901.204325192226
# AIC value: 9291.109115055724
# AIC value: 8893.326798416401
# AIC value: 9293.063478950673
# AIC value: 8895.239296994758
# AIC value: 9177.532317676301
# AIC value: 8824.724539956049
# AIC value: 9177.724966853495
# AIC value: 8899.242742241153
# AIC value: 9175.874213948175
# AIC value: 8827.911824080325
# AIC value: 9186.059669298611
# AIC value: 8831.885225944843
# AIC value: 9293.072499253027
# AIC value: 8895.239972883539
# AIC value: 9295.07581501051
# AIC value: 8897.240490419337
# AIC value: 9177.456666208887
# AIC value: 8899.239248925474
# AIC value: 9118.96546175972
# AIC value: 8803.376796475684
# AIC value: 9110.265496720178
# AIC value: 8784.384460472615
# AIC value: 9195.283235745435
# AIC value: 8865.897970676884
# AIC value: 9294.983691281985
# AIC value: 8897.237640507097
# AIC value: 9232.813233445038
# AIC value: 8899.237128725761
# AIC value: 9175.207183238268
# AIC value: 8901.23777048547
# AIC value: 9134.177464282733
# AIC value: 8903.233596828366
# AIC value: 9145.46374845837
# AIC value: 8800.21983535053
# AIC value: 9072.789418584929
# AIC value: 8786.252634099726
# AIC value: 9296.572779394934
# AIC value: 8899.154889937468
# AIC value: 9298.470605925779
# AIC value: 8857.743537492071
# AIC value: 9217.88790087146
# AIC value: 8831.832938306774
# AIC value: 9211.327366161411
# AIC value: 8867.171122768194
# AIC value: 9068.134881351605
# AIC value: 8785.52208381813
# AIC value: 9175.394985392482
# AIC value: 8852.450615083922
#       parameters          aic
# 45  (3, 4, 1, 0)  8784.384460
# 69  (5, 4, 1, 0)  8785.522084
# 59  (4, 5, 1, 0)  8786.252634
# 57  (4, 4, 1, 0)  8800.219835
# 43  (3, 3, 1, 0)  8803.376796
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(3, 1, 4)x(1, 1, [], 12)   Log Likelihood               -4383.192
# Date:                             Mon, 12 Dec 2022   AIC                           8784.384
# Time:                                     21:14:43   BIC                           8831.032
# Sample:                                          0   HQIC                          8801.876
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6664      0.025    -27.140      0.000      -0.715      -0.618
# ar.L2          0.6070      0.027     22.846      0.000       0.555       0.659
# ar.L3          0.7890      0.019     40.705      0.000       0.751       0.827
# ma.L1          0.6637      0.226      2.930      0.003       0.220       1.108
# ma.L2         -0.7787      0.367     -2.121      0.034      -1.498      -0.059
# ma.L3         -0.9467      0.188     -5.043      0.000      -1.315      -0.579
# ma.L4          0.0620      0.035      1.771      0.077      -0.007       0.131
# ar.S.L12      -0.4940      0.018    -27.989      0.000      -0.529      -0.459
# sigma2        46.2118      9.801      4.715      0.000      27.002      65.422
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               644.47
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.11
# Prob(H) (two-sided):                  0.55   Kurtosis:                         6.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
best_params
# Out:
# (3, 4, 1, 0)

# %%
predictions = []

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(target_df[target_columns[0]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

# %%
target_columns
# Out:
# ['WindDirection', 'WindSpeed']

# %%
test, train = train_test_split(target_df[target_columns[1]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: 2865.114677767084
# AIC value: 2494.0457928720316
# AIC value: 2838.0309592140084
# AIC value: 2475.384498051049
# AIC value: 2835.6810634076364
# AIC value: 2457.8764293128097
# AIC value: 2831.6757463194435
# AIC value: 2458.350103296459
# AIC value: 2831.255154096788
# AIC value: 2454.55088200729
# AIC value: 2828.3233906952855
# AIC value: 2448.602757198526
# AIC value: 2841.232530016131
# AIC value: 2480.148195045772
# AIC value: 2750.001311556365
# AIC value: 2411.4927386214767
# AIC value: 2748.2458692130253
# AIC value: 2410.231335018065
# AIC value: 2749.472972529452
# AIC value: 2407.5846823661695
# AIC value: 2751.3456980690557
# AIC value: 2408.8380511374125
# AIC value: 2752.91406136953
# AIC value: 2410.4365577759386
# AIC value: 2839.132690887616
# AIC value: 2463.0815975985943
# AIC value: 2748.043006396411
# AIC value: 2410.6914906676325
# AIC value: 2698.29086100685
# AIC value: 2379.1561180402896
# AIC value: 2688.5707890588474
# AIC value: 2372.2116245075267
# AIC value: 2683.8549596730227
# AIC value: 2373.66365886837
# AIC value: 2684.3679597095634
# AIC value: 2375.614008496883
# AIC value: 2836.042180352922
# AIC value: 2464.2404828838316
# AIC value: 2749.5106030948928
# AIC value: 2407.234755744977
# AIC value: 2686.1598373936067
# AIC value: 2372.741626073661
# AIC value: 2669.1028895103036
# AIC value: 2405.4942989632323
# AIC value: 2632.406156153538
# AIC value: 2388.018534455288
# AIC value: 2632.1210095083607
# AIC value: 2377.0055131011013
# AIC value: 2835.196238689532
# AIC value: 2462.1123251890117
# AIC value: 2751.369210977627
# AIC value: 2408.5583688482147
# AIC value: 2680.640300648113
# AIC value: 2373.7391496797613
# AIC value: 2660.97961502003
# AIC value: 2366.3949575434935
# AIC value: 2603.637442343519
# AIC value: 2354.8402352356115
# AIC value: 2584.306533536259
# AIC value: 2378.2939395198455
# AIC value: 2831.6535652646853
# AIC value: 2454.686138235764
# AIC value: 2832.126194561625
# AIC value: 2450.7972454628857
# AIC value: 2679.4653634095284
# AIC value: 2375.5772638075405
# AIC value: 2649.382664346577
# AIC value: 2369.007862895448
# AIC value: 2619.2591947369224
# AIC value: 2353.281366544441
# AIC value: 2546.9930420835763
# AIC value: 2368.0854448774962
#       parameters          aic
# 69  (5, 4, 1, 0)  2353.281367
# 57  (4, 4, 1, 0)  2354.840235
# 55  (4, 3, 1, 0)  2366.394958
# 71  (5, 5, 1, 0)  2368.085445
# 67  (5, 3, 1, 0)  2369.007863
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(5, 1, 4)x(1, 1, [], 12)   Log Likelihood               -1165.641
# Date:                             Mon, 12 Dec 2022   AIC                           2353.281
# Time:                                     21:48:34   BIC                           2410.296
# Sample:                                          0   HQIC                          2374.659
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2512      0.028     -8.843      0.000      -0.307      -0.196
# ar.L2         -0.1643      0.022     -7.549      0.000      -0.207      -0.122
# ar.L3          0.0756      0.023      3.314      0.001       0.031       0.120
# ar.L4          0.7972      0.022     35.596      0.000       0.753       0.841
# ar.L5          0.0394      0.027      1.477      0.140      -0.013       0.092
# ma.L1          0.1153      1.142      0.101      0.920      -2.124       2.354
# ma.L2         -0.0293      1.275     -0.023      0.982      -2.529       2.470
# ma.L3         -0.1172      1.241     -0.094      0.925      -2.550       2.316
# ma.L4         -0.9688      1.108     -0.875      0.382      -3.140       1.202
# ar.S.L12      -0.4735      0.024    -19.921      0.000      -0.520      -0.427
# sigma2         0.3402      0.389      0.876      0.381      -0.421       1.102
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):                 6.27
# Prob(Q):                              0.76   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.78   Skew:                             0.08
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(target_df[target_columns[1]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

# %%
target_columns_flt = ['mean_WindDirection', 'mean_WindSpeed', 'gauss_WindDirection', 'gauss_WindSpeed']
index_filtered = 0

# %%
test, train = train_test_split(filtered_df[target_columns_flt[index_filtered]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: 5119.111718764923
# AIC value: 4887.680806446745
# AIC value: 3919.901420338756
# AIC value: 3704.081766404195
# AIC value: 3622.8506656763075
# AIC value: 3281.2663543819044
# AIC value: 3287.481402595964
# AIC value: 2996.7291836510476
# AIC value: 3080.3720972692568
# AIC value: 2844.2947921620507
# AIC value: 2953.5373840629513
# AIC value: 2723.4430392033446
# AIC value: 2976.603551155252
# AIC value: 2587.989094958957
# AIC value: 2978.4861966078297
# AIC value: 2587.4361992703853
# AIC value: 2976.5644303126073
# AIC value: 2586.0347724923668
# AIC value: 2821.4342141907814
# AIC value: 2558.6471386842877
# AIC value: 2818.965641105729
# AIC value: 2557.3333133468477
# AIC value: 2819.429610657282
# AIC value: 2559.0466643503523
# AIC value: 2978.4996965524715
# AIC value: 2587.700268999717
# AIC value: 2918.0346258255277
# AIC value: 2576.91532982772
# AIC value: 2919.4191426180505
# AIC value: 2577.2906901329115
# AIC value: 2818.393883475459
# AIC value: 2557.393332960601
# AIC value: 2820.364413721403
# AIC value: 2559.21519302634
# AIC value: 2751.959301880417
# AIC value: 2481.8655827695407
# AIC value: 2976.4704386958942
# AIC value: 2587.5377505887877
# AIC value: 2914.790649977806
# AIC value: 2576.904240675097
# AIC value: 2801.626946814755
# AIC value: 2481.695255429384
# AIC value: 2758.020580562779
# AIC value: 2478.4195610046017
# AIC value: 2795.784954933094
# AIC value: 2561.1186257872405
# AIC value: 2647.949020222308
# AIC value: 2438.728066523995
# AIC value: 2832.014839136244
# AIC value: 2558.39945878921
# AIC value: 2789.5715420759925
# AIC value: 2485.548413950642
# AIC value: 2761.9854326010914
# AIC value: 2478.0584509002983
# AIC value: 2745.3816892726973
# AIC value: 2440.336415547867
# AIC value: 2796.523830028069
# AIC value: 2560.247725716168
# AIC value: 2650.491590394532
# AIC value: 2504.8069157263035
# AIC value: 2824.0379068683033
# AIC value: 2558.5119680971848
# AIC value: 2732.116509145166
# AIC value: 2479.4955951440825
# AIC value: 2746.764800904252
# AIC value: 2468.7133892893826
# AIC value: 2722.1531340326414
# AIC value: 2397.994743454161
# AIC value: 2683.633883910745
# AIC value: 2403.74833326279
# AIC value: 2650.4458609174244
# AIC value: 2461.7181672510897
#       parameters          aic
# 67  (5, 3, 1, 0)  2397.994743
# 69  (5, 4, 1, 0)  2403.748333
# 47  (3, 5, 1, 0)  2438.728067
# 55  (4, 3, 1, 0)  2440.336416
# 71  (5, 5, 1, 0)  2461.718167
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(5, 1, 3)x(1, 1, [], 12)   Log Likelihood               -1188.997
# Date:                             Mon, 12 Dec 2022   AIC                           2397.995
# Time:                                     21:56:37   BIC                           2449.826
# Sample:                                          0   HQIC                          2417.429
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3496      0.024     14.564      0.000       0.303       0.397
# ar.L2          1.0426      0.018     57.756      0.000       1.007       1.078
# ar.L3          0.4662      0.026     18.046      0.000       0.416       0.517
# ar.L4         -0.7791      0.018    -43.455      0.000      -0.814      -0.744
# ar.L5         -0.1336      0.024     -5.633      0.000      -0.180      -0.087
# ma.L1          0.6377      0.011     58.081      0.000       0.616       0.659
# ma.L2         -0.5808      0.017    -34.760      0.000      -0.614      -0.548
# ma.L3         -0.9744      0.011    -86.935      0.000      -0.996      -0.952
# ar.S.L12      -0.4455      0.021    -21.203      0.000      -0.487      -0.404
# sigma2         0.3563      0.011     33.719      0.000       0.336       0.377
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.59   Jarque-Bera (JB):               234.54
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                             0.03
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(filtered_df[target_columns_flt[index_filtered]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

index_filtered += 1

# %%
index_filtered
# Out:
# 1

# %%
# index_filtered = 1 out of 3
test, train = train_test_split(filtered_df[target_columns_flt[index_filtered]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: -1846.4209599930018
# AIC value: -2178.3125471156927
# AIC value: -2852.2810276020964
# AIC value: -3147.29509407192
# AIC value: -3056.3015876049203
# AIC value: -3420.5450552967473
# AIC value: -3398.380031302837
# AIC value: -3664.764639552014
# AIC value: -3498.534148306305
# AIC value: -3767.7713563322786
# AIC value: -3641.7616055441877
# AIC value: -3851.6223656690563
# AIC value: -3549.013180211943
# AIC value: -3874.639001800938
# AIC value: -3550.4348736041247
# AIC value: -3873.782148872052
# AIC value: -3548.717694151638
# AIC value: -3873.0611408192485
# AIC value: -3671.531103089418
# AIC value: -3904.8101333277227
# AIC value: -3671.382923426181
# AIC value: -3903.0340334178886
# AIC value: -3681.8980214979993
# AIC value: -3901.1564483832963
# AIC value: -3550.3934705717056
# AIC value: -3873.685479039384
# AIC value: -3545.144940430954
# AIC value: -3870.9948406208996
# AIC value: -3606.270493234995
# AIC value: -3886.8996128065496
# AIC value: -3672.49209303837
# AIC value: -3902.9629044958488
# AIC value: -3667.670039259965
# AIC value: -3900.8273873315484
# AIC value: -3682.776831944301
# AIC value: -3900.2794434799807
# AIC value: -3549.122117751441
# AIC value: -3873.878417401277
# AIC value: -3604.333329734266
# AIC value: -3888.6821357481435
# AIC value: -3634.6114576515956
# AIC value: -3887.6040952335225
# AIC value: -3672.5096756701673
# AIC value: -3900.4960209659557
# AIC value: -3681.1252951758115
# AIC value: -3899.469264350492
# AIC value: -3679.8614255189405
# AIC value: -3898.513962207733
# AIC value: -3653.7584491092844
# AIC value: -3899.44104464926
# AIC value: -3652.816981632086
# AIC value: -3896.347787476932
# AIC value: -3726.3757104218885
# AIC value: -3894.215111481972
# AIC value: -3741.5401469216304
# AIC value: -3914.4631631942184
# AIC value: -3697.8992575243005
# AIC value: -3900.433261974904
# AIC value: -3682.208402937935
# AIC value: -3908.1383715825737
# AIC value: -3652.4341541508065
# AIC value: -3897.7346408979265
# AIC value: -3661.9006324532147
# AIC value: -3895.6452242869523
# AIC value: -3726.229466113985
# AIC value: -3892.8627536151216
# AIC value: -3715.7872530264945
# AIC value: -3892.646023157879
# AIC value: -3732.290499215379
# AIC value: -3937.9487250662937
# AIC value: -3678.1322397507724
# AIC value: -3907.4210520464267
#       parameters          aic
# 69  (5, 4, 1, 0) -3937.948725
# 55  (4, 3, 1, 0) -3914.463163
# 59  (4, 5, 1, 0) -3908.138372
# 71  (5, 5, 1, 0) -3907.421052
# 19  (1, 3, 1, 0) -3904.810133
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(5, 1, 4)x(1, 1, [], 12)   Log Likelihood                1979.974
# Date:                             Mon, 12 Dec 2022   AIC                          -3937.949
# Time:                                     22:04:06   BIC                          -3880.934
# Sample:                                          0   HQIC                         -3916.571
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5174      0.094      5.492      0.000       0.333       0.702
# ar.L2         -0.0839      0.084     -1.002      0.316      -0.248       0.080
# ar.L3          0.1891      0.066      2.876      0.004       0.060       0.318
# ar.L4         -0.5480      0.066     -8.346      0.000      -0.677      -0.419
# ar.L5          0.5226      0.065      8.064      0.000       0.396       0.650
# ma.L1          0.3379      0.091      3.722      0.000       0.160       0.516
# ma.L2          0.3646      0.071      5.115      0.000       0.225       0.504
# ma.L3          0.2941      0.068      4.356      0.000       0.162       0.426
# ma.L4          0.6742      0.066     10.274      0.000       0.546       0.803
# ar.S.L12      -0.4155      0.028    -14.976      0.000      -0.470      -0.361
# sigma2         0.0029      0.000     26.629      0.000       0.003       0.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):                 2.82
# Prob(Q):                              0.53   Prob(JB):                         0.24
# Heteroskedasticity (H):               0.93   Skew:                             0.04
# Prob(H) (two-sided):                  0.47   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(filtered_df[target_columns_flt[index_filtered]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

index_filtered += 1

# %%
# index_filtered = 2
test, train = train_test_split(filtered_df[target_columns_flt[index_filtered]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: 7617.961340029065
# AIC value: 7272.628738201222
# AIC value: 6236.057196301014
# AIC value: 5929.881294718474
# AIC value: 5921.279954528349
# AIC value: 5533.646367608495
# AIC value: 5905.068356938131
# AIC value: 5516.632067602522
# AIC value: 5892.504631416219
# AIC value: 5518.590024794421
# AIC value: 5887.774328635038
# AIC value: 5520.589818939536
# AIC value: 6723.151868858358
# AIC value: 6350.105960119928
# AIC value: 5946.711828958727
# AIC value: 5591.023351657164
# AIC value: 5912.015362070805
# AIC value: 5517.868630196357
# AIC value: 5839.15890535061
# AIC value: 5518.590077902336
# AIC value: 5852.063745136102
# AIC value: 5481.58733108757
# AIC value: 5842.470469632914
# AIC value: 5482.377441147961
# AIC value: 6301.330420606753
# AIC value: 5923.508752964728
# AIC value: 5910.600864050614
# AIC value: 5528.696882428573
# AIC value: 5910.571563160203
# AIC value: 5518.708528007895
# AIC value: 5850.472148940716
# AIC value: 5479.057977127486
# AIC value: 5793.72923867606
# AIC value: 5480.32897880306
# AIC value: 5793.531754631679
# AIC value: 5485.334287650881
# AIC value: 6113.554766135528
# AIC value: 5724.259085242429
# AIC value: 5910.351102448505
# AIC value: 5521.2139342044775
# AIC value: 5912.216108827625
# AIC value: 5520.669194253787
# AIC value: 5852.466176074273
# AIC value: 5480.89282751843
# AIC value: 5789.019922962317
# AIC value: 5447.904682137851
# AIC value: 5768.651726201479
# AIC value: 5455.294693828335
# AIC value: 6002.631915480162
# AIC value: 5602.1910756130055
# AIC value: 5901.7390705163125
# AIC value: 5519.54081776485
# AIC value: 5913.426811901301
# AIC value: 5521.452726644922
# AIC value: 5796.324040380773
# AIC value: 5519.159311763176
# AIC value: 5718.427033681354
# AIC value: 5503.851950622809
# AIC value: 5751.990573398557
# AIC value: 5432.967690956813
# AIC value: 5944.845400203171
# AIC value: 5556.907444984523
# AIC value: 5871.492865131762
# AIC value: 5522.387179904814
# AIC value: 5855.496799065273
# AIC value: 5492.465836714415
# AIC value: 5789.7225154542775
# AIC value: 5453.097062639568
# AIC value: 5709.350197234091
# AIC value: 5506.834858895264
# AIC value: 5768.288578832487
# AIC value: 5440.875586888067
#       parameters          aic
# 59  (4, 5, 1, 0)  5432.967691
# 71  (5, 5, 1, 0)  5440.875587
# 45  (3, 4, 1, 0)  5447.904682
# 67  (5, 3, 1, 0)  5453.097063
# 47  (3, 5, 1, 0)  5455.294694
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(4, 1, 5)x(1, 1, [], 12)   Log Likelihood               -2705.484
# Date:                             Mon, 12 Dec 2022   AIC                           5432.968
# Time:                                     22:12:44   BIC                           5489.982
# Sample:                                          0   HQIC                          5454.346
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.1425      0.034     63.104      0.000       2.076       2.209
# ar.L2         -2.2871      0.071    -32.237      0.000      -2.426      -2.148
# ar.L3          1.3088      0.072     18.259      0.000       1.168       1.449
# ar.L4         -0.2226      0.036     -6.199      0.000      -0.293      -0.152
# ma.L1         -0.7077      0.040    -17.557      0.000      -0.787      -0.629
# ma.L2         -0.1264      0.050     -2.529      0.011      -0.224      -0.028
# ma.L3          0.6770      0.033     20.461      0.000       0.612       0.742
# ma.L4         -0.3910      0.043     -9.187      0.000      -0.474      -0.308
# ma.L5         -0.4466      0.036    -12.239      0.000      -0.518      -0.375
# ar.S.L12      -0.5042      0.020    -25.538      0.000      -0.543      -0.466
# sigma2         3.5320      0.167     21.205      0.000       3.206       3.858
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):               260.81
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.05   Skew:                             0.06
# Prob(H) (two-sided):                  0.58   Kurtosis:                         5.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(filtered_df[target_columns_flt[index_filtered]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

index_filtered += 1

# %%
# index_filtered = 3
test, train = train_test_split(filtered_df[target_columns_flt[index_filtered]], test_size=0.95, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

ps = range(0, 6)
d=1
qs = range(0, 6)
Ps = range(0, 2)
D=1
Qs= range(0,1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
print (u"Models to analyse by AIC:", len(parameters_list))

results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    
    #try except for the case of wrong parameters
    try:
        model=smt.SARIMAX(train, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
        
    #print wrong parameters and go on
    # AIC criteria: 
    except ValueError:
            continue
    aic = model.aic

    # save best model, aic, parameters
    if (aic < best_aic):
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    # print('Res are:', results)
    print(f'AIC value: {model.aic}')

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
# Models to analyse by AIC: 72
#   0%|          | 0/72 [00:00<?, ?it/s]
# AIC value: 991.3776487925562
# AIC value: 634.7265555877643
# AIC value: -321.1459924951331
# AIC value: -625.3493896954998
# AIC value: -528.9010906415792
# AIC value: -900.1996111452049
# AIC value: -544.6222203438624
# AIC value: -901.3352282060935
# AIC value: -587.2962554220036
# AIC value: -911.0136246532471
# AIC value: -585.8363483872408
# AIC value: -909.5102750880258
# AIC value: 233.28271758200128
# AIC value: -86.66541948228834
# AIC value: -502.9491441821672
# AIC value: -833.53108273719
# AIC value: -527.9764987813699
# AIC value: -900.4019414813109
# AIC value: -607.1219408623516
# AIC value: -952.4045357176808
# AIC value: -651.2930325644911
# AIC value: -963.2382408947897
# AIC value: -664.1264369287885
# AIC value: -963.2045508380646
# AIC value: -245.11821143932227
# AIC value: -555.9946651667403
# AIC value: -542.2591500687893
# AIC value: -908.0773012956902
# AIC value: -542.5682005723302
# AIC value: -908.170865049849
# AIC value: -620.3489579493237
# AIC value: -961.4656486477913
# AIC value: -680.5473264276148
# AIC value: -1006.5522436246086
# AIC value: -684.1859782441978
# AIC value: -994.0620372190893
# AIC value: -376.14197820553244
# AIC value: -685.476074723425
# AIC value: -565.28380627695
# AIC value: -906.6021689464774
# AIC value: -618.4086362530069
# AIC value: -954.1095358711175
# AIC value: -616.281791884246
# AIC value: -959.6399536237927
# AIC value: -703.5406121230496
# AIC value: -1002.9757910429864
# AIC value: -718.4770604526288
# AIC value: -999.4848103268207
# AIC value: -490.22142525506706
# AIC value: -850.3112146255744
# AIC value: -580.4844841378458
# AIC value: -923.3038518843921
# AIC value: -541.1171376981682
# AIC value: -923.1039788101035
# AIC value: -678.7103402696229
# AIC value: -955.6607863139586
# AIC value: -732.8227152825114
# AIC value: -967.5559728957851
# AIC value: -735.4143811818176
# AIC value: -949.0209694729426
# AIC value: -524.0109904218386
# AIC value: -889.0587594243207
# AIC value: -614.8041571846533
# AIC value: -924.4577938258112
# AIC value: -672.7626523660754
# AIC value: -952.8102680717635
# AIC value: -716.3426412683694
# AIC value: -920.1876930453817
# AIC value: -681.6400442430001
# AIC value: -919.366447726476
# AIC value: -742.5581250024584
# AIC value: -972.0497656872867
#       parameters          aic
# 33  (2, 4, 1, 0) -1006.552244
# 45  (3, 4, 1, 0) -1002.975791
# 47  (3, 5, 1, 0)  -999.484810
# 35  (2, 5, 1, 0)  -994.062037
# 71  (5, 5, 1, 0)  -972.049766
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 1330
# Model:             SARIMAX(2, 1, 4)x(1, 1, [], 12)   Log Likelihood                 511.276
# Date:                             Mon, 12 Dec 2022   AIC                          -1006.552
# Time:                                     22:21:22   BIC                           -965.087
# Sample:                                          0   HQIC                          -991.005
#                                             - 1330
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0296      0.026      1.143      0.253      -0.021       0.080
# ar.L2          0.7824      0.026     29.622      0.000       0.731       0.834
# ma.L1          1.3456      0.055     24.612      0.000       1.238       1.453
# ma.L2         -0.4302      0.103     -4.186      0.000      -0.632      -0.229
# ma.L3         -1.3448      0.085    -15.908      0.000      -1.510      -1.179
# ma.L4         -0.5687      0.033    -17.104      0.000      -0.634      -0.504
# ar.S.L12      -0.4626      0.023    -20.227      0.000      -0.507      -0.418
# sigma2         0.0266      0.001     18.403      0.000       0.024       0.029
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                12.63
# Prob(Q):                              0.74   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
index_filtered
# Out:
# 3

# %%
nans = np.array([np.nan]*len(train))

plt.figure(figsize=(12,4))
plt.plot(np.asarray(filtered_df[target_columns_flt[index_filtered]].values))
preds_0 = smt.SARIMAX(train, order=(best_param[0], d, best_param[1]), seasonal_order=(best_param[2], D, best_param[3], 12)).fit(disp=-1).forecast(len(test))
predictions.append(preds_0)

preds_0_nan = np.hstack((nans, np.asarray(preds_0)))
plt.plot(preds_0_nan)

# index_filtered += 1

# %%
len(predictions)
# Out:
# 6

# %% [markdown]
# Seasonality about 80-115 intervals - auto_arima can't calculate models - RAM error (it consumes too much memory)

# %%
auto_arima(target_df[column], seasonal=True,
                      test='adf',error_action='ignore',
                      suppress_warnings=True, m=12, start_p=1, max_p=12,
                      stepwise=True, trace=True,start_q=1, max_q=12,)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=3.94 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4428.532, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1629.333, Time=2.35 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2934.014, Time=0.64 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=8722.749, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=1630.019, Time=0.25 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=1631.064, Time=7.05 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=3.61 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=1629.415, Time=1.00 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=6.55 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=3887.304, Time=0.98 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=1623.594, Time=3.63 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=1623.701, Time=0.46 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=1625.606, Time=9.15 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=3.16 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=1623.634, Time=1.34 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=9.64 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=1610.732, Time=4.52 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=1609.485, Time=0.42 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=1610.753, Time=1.62 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=5.73 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=1611.299, Time=0.41 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1611.285, Time=0.82 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=inf, Time=1.38 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1613.295, Time=0.65 sec
#  ARIMA(3,0,0)(0,0,0)[12]             : AIC=inf, Time=0.12 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[12] intercept
# Total fit time: 69.534 seconds
# ARIMA(order=(3, 0, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)

# %%
ls_auto_arima = []
for column in target_columns:
  ls_auto_arima.append(auto_arima(target_df[column], seasonal=True,
                      start_p=0, start_q=0, max_order=5, test='adf',error_action='ignore',
                      suppress_warnings=True, m=12,
                      stepwise=True, trace=True))
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=11522.035, Time=2.51 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=11885.590, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=8923.674, Time=2.00 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=10395.212, Time=1.33 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=18191.660, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=8924.622, Time=0.10 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=8925.389, Time=6.39 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.90 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=8923.768, Time=1.27 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=7.51 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=11507.807, Time=2.38 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=8925.269, Time=3.05 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=8925.218, Time=3.75 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=11165.948, Time=3.44 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=8925.918, Time=3.99 sec
#  ARIMA(1,0,0)(1,0,0)[12]             : AIC=inf, Time=0.75 sec
#
# Best model:  ARIMA(1,0,0)(1,0,0)[12] intercept
# Total fit time: 41.470 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=3887.408, Time=1.89 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=4428.532, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1629.333, Time=2.31 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=2934.014, Time=0.69 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=8722.749, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=1630.019, Time=0.24 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=1631.064, Time=7.09 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=3.55 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=1629.415, Time=0.99 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=5.71 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=3887.304, Time=0.99 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=1623.594, Time=3.64 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=1623.701, Time=0.48 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=1625.606, Time=13.73 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=5.15 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=1623.634, Time=2.43 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=9.64 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=1610.732, Time=4.53 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=1609.485, Time=0.42 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=1610.753, Time=1.63 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=5.84 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=1611.299, Time=0.46 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=1611.285, Time=0.82 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=inf, Time=1.40 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=1613.295, Time=0.67 sec
#  ARIMA(3,0,0)(0,0,0)[12]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[12] intercept
# Total fit time: 74.521 seconds

# %%
ls_auto_arima = []
for column in target_columns:
  ls_auto_arima.append(auto_arima(target_df[column], seasonal=True,
                      start_p=0, start_q=0, max_order=5, test='adf',error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True, trace=True))
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=11885.590, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8924.622, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=10568.306, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18191.660, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=8926.338, Time=0.22 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=8926.305, Time=0.37 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=8926.988, Time=1.28 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 2.663 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4957.734, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1996.984, Time=0.25 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=3668.758, Time=0.19 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8672.283, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=1984.735, Time=0.32 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=1973.294, Time=0.41 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=1975.073, Time=0.57 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=1973.564, Time=2.01 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=1971.725, Time=1.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1981.249, Time=0.54 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1973.503, Time=1.84 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=1972.003, Time=0.86 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=1971.482, Time=4.28 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=1973.671, Time=4.20 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=1973.636, Time=3.59 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=1991.892, Time=3.06 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=1977.153, Time=1.34 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=2364.441, Time=3.35 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=1.29 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0] intercept
# Total fit time: 29.236 seconds

# %%
for info in ls_auto_arima:
  print(info.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1400
# Model:               SARIMAX(1, 0, 0)   Log Likelihood               -4459.311
# Date:                Sat, 10 Dec 2022   AIC                           8924.622
# Time:                        11:06:15   BIC                           8940.355
# Sample:                             0   HQIC                          8930.503
#                                - 1400
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      9.2977      1.412      6.584      0.000       6.530      12.065
# ar.L1          0.9415      0.009    105.718      0.000       0.924       0.959
# sigma2        34.1632      0.675     50.635      0.000      32.841      35.486
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.25   Jarque-Bera (JB):              1830.52
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                            -0.31
# Prob(H) (two-sided):                  0.91   Kurtosis:                         8.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1400
# Model:               SARIMAX(3, 0, 2)   Log Likelihood                -978.741
# Date:                Sat, 10 Dec 2022   AIC                           1971.482
# Time:                        11:06:15   BIC                           2008.191
# Sample:                             0   HQIC                          1985.205
#                                - 1400
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.1550      0.069      2.263      0.024       0.021       0.289
# ar.L1          0.5001      0.114      4.400      0.000       0.277       0.723
# ar.L2          0.9202      0.052     17.571      0.000       0.818       1.023
# ar.L3         -0.4506      0.108     -4.177      0.000      -0.662      -0.239
# ma.L1          0.3298      0.104      3.172      0.002       0.126       0.534
# ma.L2         -0.6240      0.104     -6.007      0.000      -0.828      -0.420
# sigma2         0.2366      0.007     31.607      0.000       0.222       0.251
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                71.79
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.77   Skew:                             0.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
target_columns_flt = ['mean_WindDirection', 'mean_WindSpeed', 'gauss_WindDirection', 'gauss_WindSpeed']

# %%
ls_auto_arima = []
for column in target_columns_flt:
  ls_auto_arima.append(auto_arima(filtered_df[column], seasonal=True,
                      start_p=0, start_q=0, max_order=5, test='adf',error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True, trace=True))
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=11493.858, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18190.055, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=3743.206, Time=1.24 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=3067.389, Time=0.70 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=3124.414, Time=0.24 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=3067.985, Time=1.53 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=3067.498, Time=1.53 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=3541.732, Time=2.17 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=3077.241, Time=1.60 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=3055.962, Time=1.90 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=2967.620, Time=2.04 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=3011.933, Time=1.73 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.79 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=3102.063, Time=2.70 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=3024.994, Time=2.11 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=3010.188, Time=2.21 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=2967.595, Time=2.96 sec
#  ARIMA(5,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=4.75 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=2961.743, Time=4.63 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=2.78 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=2991.389, Time=3.51 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=3008.164, Time=3.48 sec
#  ARIMA(5,0,5)(0,0,0)[0] intercept   : AIC=2969.735, Time=3.50 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=3017.062, Time=1.66 sec
#
# Best model:  ARIMA(4,0,4)(0,0,0)[0] intercept
# Total fit time: 52.275 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4630.541, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=2766.424, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8659.183, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=-3035.955, Time=0.35 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-3605.701, Time=1.37 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-3442.048, Time=0.21 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-3623.092, Time=1.54 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-3624.373, Time=0.67 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=-3622.877, Time=1.04 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=-3620.670, Time=2.44 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.59 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[0] intercept
# Total fit time: 8.677 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=11801.345, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=7230.867, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18190.757, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=6235.859, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=5806.544, Time=0.52 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=5557.299, Time=0.30 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=5438.310, Time=0.51 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=5348.345, Time=2.87 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=5348.903, Time=1.22 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=5350.729, Time=2.51 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=5347.944, Time=2.18 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=5346.747, Time=1.71 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=5345.054, Time=1.11 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=5364.986, Time=0.87 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=5438.121, Time=0.73 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=5346.559, Time=3.66 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=5842.092, Time=1.79 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=5344.626, Time=2.01 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=7069.524, Time=0.93 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=5346.572, Time=1.62 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=8255.407, Time=0.77 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=6406.808, Time=1.57 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=5347.433, Time=2.50 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=5381.768, Time=0.71 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 30.949 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=4879.228, Time=0.11 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8.953, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=8666.904, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=-780.569, Time=0.27 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=-1219.694, Time=0.48 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=-1387.031, Time=0.38 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=-1539.387, Time=0.68 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=-1536.880, Time=2.69 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=-1601.954, Time=2.08 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=-1598.969, Time=1.59 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-1595.143, Time=2.13 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-1595.189, Time=1.68 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=-1608.813, Time=2.59 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=-1609.280, Time=2.98 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=-1603.684, Time=2.38 sec
#  ARIMA(5,0,4)(0,0,0)[0] intercept   : AIC=-1606.835, Time=3.13 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=-1601.701, Time=2.72 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=-1592.360, Time=1.31 sec
#
# Best model:  ARIMA(5,0,3)(0,0,0)[0] intercept
# Total fit time: 28.028 seconds

# %%
coefficients = [(4,0,4), (3,0,0), (1,0,3), (5,0,3)]

# %%
for info in ls_auto_arima:
  print(info)
# Out:
#  ARIMA(4,0,4)(0,0,0)[0] intercept
#  ARIMA(3,0,0)(0,0,0)[0] intercept
#  ARIMA(1,0,3)(0,0,0)[0] intercept
#  ARIMA(5,0,3)(0,0,0)[0] intercept

# %%
filtered_df

# %%
target_columns

# %%
from scipy.stats import shapiro

# %%
test, train = train_test_split(target_df[target_columns[0]], test_size=0.98, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

model = SARIMAX(train, order = (1,0,0),seasonal_order = (0,0,0,0))
# model = ARIMA(train, order=(1,0,0))
fitted = model.fit()

residuals = pd.DataFrame(fitted.resid)
sns.distplot(residuals, kde=True, norm_hist=True)
plt.title(f'Distribution of residual for {target_columns[0]}')
print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
plt.show()

forecast_test = fitted.forecast(len(test))
fc = forecast_test

d = {'target':  pd.Series(test), 'pred': fc}
df = pd.DataFrame(d)

# df.plot()
plt.plot(test)
plt.plot(fc)
plt.title(f'{target_columns[0]} value')
plt.xlim(0,30)
# Out:
# Residuals mean: 0    0.200491
# dtype: float64
# Residuals std: 0    7.391484
# dtype: float64
# ShapiroResult(statistic=0.6444714069366455, pvalue=0.0)
# (0.0, 30.0)

# %%
test, train = train_test_split(target_df[target_columns[1]], test_size=0.98, shuffle = False, random_state=42)
train = np.asarray(train, dtype=np.float)
test = np.asarray(test, dtype=np.float)

# model = ARIMA(train, order=(1,1,3))
model = SARIMAX(train, order = (3,0,2),seasonal_order = (0,0,0,0))
fitted = model.fit()

residuals = pd.DataFrame(fitted.resid)
sns.distplot(residuals, kde=True, norm_hist=True)
plt.title(f'Distribution of residual for {target_columns[1]}')
print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
plt.show()

forecast_test = fitted.forecast(len(test))
fc = forecast_test #pd.Series([None]*len(train) + list(forecast_test))

d = {'target':  pd.Series(test), 'pred': fc}
df = pd.DataFrame(d)

df.plot()
plt.title(f'{target_columns[1]} value')
plt.xlim(0,30)
# Out:
# Residuals mean: 0    0.017962
# dtype: float64
# Residuals std: 0    0.43559
# dtype: float64
# ShapiroResult(statistic=0.9714770317077637, pvalue=7.938447309413282e-16)
# (0.0, 30.0)

# %%
target_predictions = predictions[0:2]
len(target_predictions)
# Out:
# 2

# %%
from scipy.stats import shapiro

# %%
for i in range(len(target_columns)):
  residuals = target_df[target_columns[i]][-len(test):] - target_predictions[i]
  sns.distplot(residuals, kde=True, norm_hist=True)
  plt.title(f'Distribution of residual for {target_columns[i]}')
  print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
  plt.tight_layout()
  plt.show()
# Out:
# Residuals mean: 51.94364727485102
# Residuals std: 23.570527593053814
# ShapiroResult(statistic=0.9872443675994873, pvalue=0.7005686163902283)
# Residuals mean: 1.4546944791668317
# Residuals std: 0.8779924905502712
# ShapiroResult(statistic=0.9724649786949158, pvalue=0.12562914192676544)

# %%
filtered_predictions = predictions[2:]
len(filtered_predictions)
# Out:
# 4

# %%
for i in range(len(target_columns_flt)):
  residuals = filtered_df[target_columns_flt[i]][-len(test):] - filtered_predictions[i]
  sns.distplot(residuals, kde=True, norm_hist=True)
  plt.title(f'Distribution of residual for {target_columns_flt[i]}')
  print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
  plt.tight_layout()
  plt.show()
# Out:
# Residuals mean: 25.895415116555608
# Residuals std: 21.434616655966714
# ShapiroResult(statistic=0.9618000984191895, pvalue=0.03149845078587532)
# Residuals mean: 3.0516113193450587
# Residuals std: 1.580143264909894
# ShapiroResult(statistic=0.7839896082878113, pvalue=9.182869575852237e-09)
# Residuals mean: 50.30433179621342
# Residuals std: 21.83575754824047
# ShapiroResult(statistic=0.9859229326248169, pvalue=0.622359037399292)
# Residuals mean: 1.548557002169439
# Residuals std: 0.8224439410613178
# ShapiroResult(statistic=0.942756175994873, pvalue=0.003083009971305728)

# %%
fitted_sr = []
for i in range(len(target_columns_flt)):
  test, train = train_test_split(filtered_df[target_columns_flt[i]], test_size=0.98, shuffle = False, random_state=42)
  train = np.asarray(train, dtype=np.float)
  test = np.asarray(test, dtype=np.float)




  model = SARIMAX(train, order = coefficients[i],seasonal_order = (0,0,0,0))
  fitted = model.fit(disp = 0)

  # model = ARIMA(train, order=(coefficients[i]))
  # fitted = model.fit()
  fitted_sr.append(fitted)

  residuals = pd.DataFrame(fitted.resid)
  sns.distplot(residuals, kde=True, norm_hist=True)
  plt.title(f'Distribution of residual for {target_columns_flt[i]}')
  print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
  plt.tight_layout()
  plt.show()
# Out:
# Residuals mean: 0    0.128867
# dtype: float64
# Residuals std: 0    4.851007
# dtype: float64
# ShapiroResult(statistic=0.05274909734725952, pvalue=0.0)
# Residuals mean: 0    0.003774
# dtype: float64
# Residuals std: 0    0.107963
# dtype: float64
# ShapiroResult(statistic=0.24571067094802856, pvalue=0.0)
# Residuals mean: 0    0.147607
# dtype: float64
# Residuals std: 0    4.938811
# dtype: float64
# ShapiroResult(statistic=0.17245787382125854, pvalue=0.0)
# Residuals mean: 0    0.00699
# dtype: float64
# Residuals std: 0    0.14712
# dtype: float64
# ShapiroResult(statistic=0.9114965200424194, pvalue=1.5496776704463205e-27)

# %%
i = 0
for item in fitted_sr:
  forecast_test = item.forecast(len(test))


  # output = model_fit.forecast()

  # yhat = output[0]
  # predictions.append(float(yhat))

  # obs = test[t]
  # history.append(obs)

  # print('predicted = %f, expected = %f' % (np.exp(yhat), np.exp(obs)))


  d = {'target':  pd.Series(test), 'pred': forecast_test}
  df = pd.DataFrame(d)

  
  plt.xlim(0,30)
  
  df.plot()
  plt.title(f'{target_columns_flt[i]} value')
  i += 1

# %% [markdown]
# # Step 7 - Build model in a form of linear dynamical system, using chosen predictors. To analyze residual error and to define appropriate order of model.

# %%
def wrap_into_input(forecast_length, feature_time_series, target_time_series):
    task = Task(TaskTypesEnum.ts_forecasting,
                TsForecastingParams(forecast_length=forecast_length))

    input_data = InputData(idx=np.arange(0, len(target_time_series)),
                           features=feature_time_series, target=target_time_series,
                           task=task, data_type=DataTypesEnum.ts)

    return input_data

def ts(target, predictor1, predictor2, predictor3, predictor4, forecast_length):
    ts_1 = wrap_into_input(forecast_length = forecast_length,
                           feature_time_series = np.array(target),
                           target_time_series = np.array(target))

    ts_2 = wrap_into_input(forecast_length = forecast_length,
                           feature_time_series = np.array(predictor1),
                           target_time_series = np.array(target))

    ts_3 = wrap_into_input(forecast_length = forecast_length,
                           feature_time_series = np.array(predictor2),
                           target_time_series = np.array(target))

    ts_4 = wrap_into_input(forecast_length = forecast_length,
                           feature_time_series = np.array(predictor3),
                           target_time_series = np.array(target))

    ts_5 = wrap_into_input(forecast_length = forecast_length,
                           feature_time_series = np.array(predictor4),
                           target_time_series = np.array(target))

    dataset = MultiModalData({
        f'data_source_ts/{target}': ts_1,
        f'data_source_ts/{predictor1}': ts_2,
        f'data_source_ts/{predictor2}': ts_3,
        f'data_source_ts/{predictor3}': ts_4,
        f'data_source_ts/{predictor4}': ts_5
    })

    return ts_1, ts_2, ts_3, ts_4, ts_5, dataset

def create_multisource_pipeline(target, predictor1, predictor2, predictor3, predictor4):
    """ Generate pipeline with several data sources """
    node_source_1 = PrimaryNode(f'data_source_ts/{target}')
    node_source_2 = PrimaryNode(f'data_source_ts/{predictor1}')
    node_source_3 = PrimaryNode(f'data_source_ts/{predictor2}')
    node_source_4 = PrimaryNode(f'data_source_ts/{predictor3}')
    node_source_5 = PrimaryNode(f'data_source_ts/{predictor4}')

    node_lagged_1 = SecondaryNode('lagged', nodes_from=[node_source_1])
    node_lagged_2 = SecondaryNode('lagged', nodes_from=[node_source_2])
    node_lagged_3 = SecondaryNode('lagged', nodes_from=[node_source_3])
    node_lagged_4 = SecondaryNode('lagged', nodes_from=[node_source_4])
    node_lagged_5 = SecondaryNode('lagged', nodes_from=[node_source_5])

    node_ridge = SecondaryNode('ridge', nodes_from=[node_lagged_1])
    node_lasso_2 = SecondaryNode('lasso', nodes_from=[node_lagged_2])
    node_lasso_3 = SecondaryNode('lasso', nodes_from=[node_lagged_3])
    node_lasso_4 = SecondaryNode('lasso', nodes_from=[node_lagged_4])
    node_lasso_5 = SecondaryNode('lasso', nodes_from=[node_lagged_5])

    # node_ridge = SecondaryNode('ridge', nodes_from=[node_source_1])
    # node_lasso_2 = SecondaryNode('lasso', nodes_from=[node_source_2])
    # node_lasso_3 = SecondaryNode('lasso', nodes_from=[node_source_3])
    # node_lasso_4 = SecondaryNode('lasso', nodes_from=[node_source_4])
    # node_lasso_5 = SecondaryNode('lasso', nodes_from=[node_source_5])

    node_final = SecondaryNode('linear', nodes_from=[node_ridge, node_lasso_2, node_lasso_3, node_lasso_4, node_lasso_5])
    pipeline = Pipeline(node_final)
    return pipeline

# %%
# target_columns = ['WindDirection', 'WindSpeed']
# predict_columns = ['ActivePower', 'RotorRPM', 'AmbientTemperatue', 'ReactivePower']

# %%
forecast_length = 100

target = target_df['WindSpeed']
predictor1 = target_df['ActivePower']
predictor2 = target_df['RotorRPM']
predictor3 = target_df['AmbientTemperatue']
predictor4 = target_df['ReactivePower']

ts_1, ts_2, ts_3, ts_4, ts_5, dataset = ts(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4, forecast_length = forecast_length)

train, test = train_test_data_setup(dataset)

pipeline = create_multisource_pipeline(target = 'WindSpeed', predictor1 = 'ActivePower', predictor2 = 'RotorRPM', predictor3 = 'AmbientTemperatue', predictor4 = 'ReactivePower',)
pipeline.show()
# Out:
# WARNING:root:OperationTypesRepository - Operation lagged not found in the repository
# 2022-12-10 12:15:06,278 - OperationTypesRepository - Operation lagged not found in the repository
# WARNING:root:OperationTypesRepository - Operation data_source_ts not found in the repository
# 2022-12-10 12:15:06,283 - OperationTypesRepository - Operation data_source_ts not found in the repository
# WARNING:root:OperationTypesRepository - Operation lagged not found in the repository
# 2022-12-10 12:15:06,287 - OperationTypesRepository - Operation lagged not found in the repository
# WARNING:root:OperationTypesRepository - Operation data_source_ts not found in the repository
# 2022-12-10 12:15:06,291 - OperationTypesRepository - Operation data_source_ts not found in the repository
# WARNING:root:OperationTypesRepository - Operation lagged not found in the repository
# 2022-12-10 12:15:06,294 - OperationTypesRepository - Operation lagged not found in the repository
# WARNING:root:OperationTypesRepository - Operation data_source_ts not found in the repository
# 2022-12-10 12:15:06,297 - OperationTypesRepository - Operation data_source_ts not found in the repository
# WARNING:root:OperationTypesRepository - Operation lagged not found in the repository
# 2022-12-10 12:15:06,299 - OperationTypesRepository - Operation lagged not found in the repository
# WARNING:root:OperationTypesRepository - Operation data_source_ts not found in the repository
# 2022-12-10 12:15:06,302 - OperationTypesRepository - Operation data_source_ts not found in the repository
# WARNING:root:OperationTypesRepository - Operation lagged not found in the repository
# 2022-12-10 12:15:06,305 - OperationTypesRepository - Operation lagged not found in the repository
# WARNING:root:OperationTypesRepository - Operation data_source_ts not found in the repository
# 2022-12-10 12:15:06,307 - OperationTypesRepository - Operation data_source_ts not found in the repository

# %%
pipeline = create_multisource_pipeline(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4)

pipeline.fit(train)
forecast = pipeline.predict(test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
nans = np.array([np.nan]*len(target_df['Date']))
forecast_df = target_df[['Date']+target_columns]
forecast_df['ForWindSpeed'] = nans#forecast_df['WindSpeed']

pred_fore1 = forecast.predict
part_col = nans#np.asarray(target_df['WindSpeed'], dtype=np.float)
part_col[len(target_df['Date'])-forecast_length:] = pred_fore1.reshape(-1)
forecast_df['ForWindSpeed'] = part_col

plt.figure(figsize=(12,10))
plt.plot(forecast_df.WindSpeed, label='Actual time series')
plt.plot(forecast_df.ForWindSpeed, label='Forecast')
plt.legend()
plt.grid()
plt.show()

target_value = np.asarray(target_df['WindSpeed'], dtype=np.float)
metric = mean_absolute_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict))
print(f'MAE metric value: {metric:.2f}')
print('MSE:', mean_squared_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict)))
# Out:
# MAE metric value: 0.80
# MSE: 0.9519378398712093

# %%
residuals = target_value[len(target_df['Date'])-forecast_length:] - np.ravel(forecast.predict)
sns.distplot(residuals, kde=True, norm_hist=True)
plt.title(f'Distribution of residual for {item}')
print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
plt.show()
# Out:
# Residuals mean: 0.3658496427536011
# Residuals std: 0.9044843164855163
# ShapiroResult(statistic=0.9386483430862427, pvalue=0.0001596113870618865)

# %%
forecast_length = 100

target = target_df['WindDirection']
predictor1 = target_df['ActivePower']
predictor2 = target_df['RotorRPM']
predictor3 = target_df['AmbientTemperatue']
predictor4 = target_df['ReactivePower']

ts_1, ts_2, ts_3, ts_4, ts_5, dataset = ts(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4, forecast_length = forecast_length)

train, test = train_test_data_setup(dataset)

pipeline = create_multisource_pipeline(target = 'WindDirection', predictor1 = 'ActivePower', predictor2 = 'RotorRPM', predictor3 = 'AmbientTemperatue', predictor4 = 'ReactivePower',)
# pipeline.show()
pipeline = create_multisource_pipeline(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4)

pipeline.fit(train)
forecast = pipeline.predict(test)

# %%
nans = np.array([np.nan]*len(target_df['Date']))
forecast_df = target_df[['Date']+target_columns]
forecast_df['ForWindDirect'] = nans

pred_fore = forecast.predict
part_col = nans
part_col[len(target_df['Date'])-forecast_length:] = pred_fore.reshape(-1)
forecast_df['ForWindDirect'] = part_col

plt.figure(figsize=(12,10))
plt.plot(forecast_df.WindDirection, label='Actual time series')
plt.plot(forecast_df.ForWindDirect, label='Forecast')
plt.legend()
plt.grid()
plt.show()

target_value = np.asarray(target_df['WindDirection'], dtype=np.float)
metric = mean_absolute_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict))
print(f'MAE metric value: {metric:.2f}')
print('MSE:', mean_squared_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict)))
# Out:
# MAE metric value: 29.34
# MSE: 1416.802649713274

# %%
residuals = target_value[len(target_df['Date'])-forecast_length:] - np.ravel(forecast.predict)
sns.distplot(residuals, kde=True, norm_hist=True)
plt.title(f'Distribution of residual for {item}')
print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
plt.show()
# Out:
# Residuals mean: 2.502852813852815
# Residuals std: 37.55713484153794
# ShapiroResult(statistic=0.9782854318618774, pvalue=0.09764482825994492)

# %%
# filtered_df
# filtered_df.mean_WindSpeed
# Out:
#                            Date  WindDirection  WindSpeed  ActivePower  \
# 30000 2019-11-25 18:20:00+00:00          173.5   5.848312   484.811382
# 30001 2019-11-25 18:30:00+00:00         175.75   5.926594   473.886145
# 30002 2019-11-25 18:40:00+00:00          169.0   5.654822   410.817685
# 30003 2019-11-25 18:50:00+00:00          169.0   5.743376   425.636621
# 30004 2019-11-25 19:00:00+00:00          169.0   5.601631   403.702268
# ...                         ...            ...        ...          ...
# 31395 2019-12-07 13:30:00+00:00          164.2   6.670898    -5.703843
# 31396 2019-12-07 13:40:00+00:00         148.25   6.496094    -5.776515
# 31397 2019-12-07 13:50:00+00:00          129.0   6.526367    -5.297811
# 31398 2019-12-07 14:00:00+00:00          114.0   6.375977     -5.47912
# 31399 2019-12-07 14:10:00+00:00     103.666667   6.217285    -5.562889
#
#         RotorRPM  AmbientTemperatue  ReactivePower mean_WindDirection  \
# 30000  10.401707          23.135894      99.035418              173.5
# 30001  10.434384          23.044191      97.104932             175.75
# 30002   9.859029          22.896918      83.383613              169.0
# 30003   10.05716          22.825172      86.624567              169.0
# 30004   9.886101          22.820358      82.993174              169.0
# ...          ...                ...            ...                ...
# 31395        0.0          22.659033      -13.59253         189.805556
# 31396        0.0          22.689633     -13.317937         186.955556
# 31397        0.0          22.614557     -12.133637         182.822222
# 31398        0.0          22.690502     -11.476812         177.288889
# 31399        0.0           22.71652     -12.447525         170.933333
#
#       mean_WindSpeed  gauss_WindDirection  gauss_WindSpeed
# 30000       5.848312           173.937919         5.862186
# 30001       5.926594           173.248563         5.832516
# 30002       5.654822           170.798398         5.746862
# 30003       5.743376           169.446212         5.697815
# 30004       5.601631           170.551296         5.684361
# ...              ...                  ...              ...
# 31395       2.550689           164.347317         1.881887
# 31396       2.473547           147.436605         1.727266
# 31397       2.422593           130.434652         1.660923
# 31398       2.342366           116.101226         1.502575
# 31399       2.259005           107.598038         1.400353
#
# [1400 rows x 11 columns]

# %%
forecast_length = 100

target = filtered_df['mean_WindSpeed']
predictor1 = target_df['ActivePower']
predictor2 = target_df['RotorRPM']
predictor3 = target_df['AmbientTemperatue']
predictor4 = target_df['ReactivePower']

ts_1, ts_2, ts_3, ts_4, ts_5, dataset = ts(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4, forecast_length = forecast_length)

train, test = train_test_data_setup(dataset)

pipeline = create_multisource_pipeline(target = 'mean_WindSpeed', predictor1 = 'ActivePower', predictor2 = 'RotorRPM', predictor3 = 'AmbientTemperatue', predictor4 = 'ReactivePower',)
# pipeline.show()
pipeline = create_multisource_pipeline(target = target, predictor1 = predictor1, predictor2 = predictor2, predictor3 = predictor3, predictor4 = predictor4)

pipeline.fit(train)
forecast = pipeline.predict(test)

# %%
nans = np.array([np.nan]*len(target_df['Date']))
forecast_df = filtered_df[['Date', 'mean_WindSpeed']+target_columns]
forecast_df['ForMeanWindSpeed'] = nans

pred_fore = forecast.predict
part_col = nans
part_col[len(target_df['Date'])-forecast_length:] = pred_fore.reshape(-1)
forecast_df['ForMeanWindSpeed'] = part_col

plt.figure(figsize=(12,10))
plt.plot(forecast_df.mean_WindSpeed, label='Actual time series')
plt.plot(forecast_df.ForMeanWindSpeed, label='Forecast')
plt.legend()
plt.grid()
plt.show()

target_value = np.asarray(filtered_df['mean_WindSpeed'], dtype=np.float)
metric = mean_absolute_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict))
print(f'MAE metric value: {metric:.2f}')
print('MSE:', mean_squared_error(target_value[len(target_df['Date'])-forecast_length:], np.ravel(forecast.predict)))
# Out:
# MAE metric value: 2.06
# MSE: 6.267714898906906

# %%
residuals = target_value[len(target_df['Date'])-forecast_length:] - np.ravel(forecast.predict)
sns.distplot(residuals, kde=True, norm_hist=True)
plt.title(f'Distribution of residual for {item}')
print(f'Residuals mean: {residuals.mean()} \nResiduals std: {residuals.std()}\n{shapiro(residuals)}')
plt.show()
# Out:
# Residuals mean: -1.931583970729253
# Residuals std: 1.5927015611622655
# ShapiroResult(statistic=0.8957126140594482, pvalue=8.936877975429525e-07)
